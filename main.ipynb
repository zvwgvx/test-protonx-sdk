# %%
from dotenv import load_dotenv

load_dotenv(".env")
# print(os.getenv("PROTONX_API_KEY"))
# Out:
# True

# %%
from protonx import ProtonX
client = ProtonX()
client.embeddings.create(input=["Chào bạn"])
# Out:
# {'data': [{'index': 0,
#    'embedding': [-0.05731881409883499,
#     0.05940623581409454,
#     -0.05134158208966255,
#     0.027673514559864998,
#     -0.0025757497642189264,
#     0.008206188678741455,
#     -0.02638399600982666,
#     0.08952873945236206,
#     0.03925943747162819,
#     -0.061169009655714035,
#     -0.02158801630139351,
#     0.005942053627222776,
#     -0.11568114161491394,
#     0.07865042239427567,
#     -0.04377184808254242,
#     0.05500704422593117,
#     0.15672075748443604,
#     0.04782978817820549,
#     -0.014383264817297459,
#     0.022678013890981674,
#     0.01427352987229824,
#     -0.009108235128223896,
#     -0.052527423948049545,
#     0.023526668548583984,
#     -0.02246234565973282,
#     0.04578396677970886,
#     0.1207704246044159,
#     -0.03536442667245865,
#     -0.060805343091487885,
#     -0.015196767635643482,
#     -0.10845702886581421,
#     -0.03839857131242752,
#     0.00998632051050663,
#     0.03399565443396568,
# ...
